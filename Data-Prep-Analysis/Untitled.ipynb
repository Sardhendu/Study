# %%
from __future__ import division

import pandas as pd
import numpy as np
datadir = '/Users/sam/All-Program/App-DataSet/Study/Data-Prep-Analysis/Lecture_13_Python_Code_and_Data/train.csv'

# %%
data = pd.read_csv(datadir)

# %%
data.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
np.unique(data['Property_Area'])
# Out:
# array(['Rural', 'Semiurban', 'Urban'], dtype=object)

# %%
data.groupby('Married').count()
# Out:
#          Loan_ID  Gender  Dependents  Education  Self_Employed  \
# Married
# No           213     210         209        213            199
# Yes          398     388         390        398            380
#
#          ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Married
# No                   213                213         206               208
# Yes                  398                398         384               389
#
#          Credit_History  Property_Area  Loan_Status
# Married
# No                  199            213          213
# Yes                 362            398          398

# %%
# data.plot(CoapplicantIncome, 'line')
import matplotlib.pyplot as plt
import matplotlib
from pandas.tools.plotting import scatter_matrix
matplotlib.style.use('ggplot')
# %matplotlib inline

fig, ax = plt.subplots(1, 1, figsize=(25,10), facecolor='w', edgecolor='k')
data['CoapplicantIncome'].plot.hist( ax=ax)

# %%
# Loan_Status
# Education

# newDF  = data.groupby('Education').count()
# newDF1  = data.groupby('Loan_Status').count()

arr = data['Loan_Status']
arr2 = data['Education']
# print (arr)
ind1 = np.where(arr=='Y')[0]
ind2 = np.where(arr2=='Graduate')[0]

len(np.intersect1d(ind1, ind2))/data.shape[0]



#data.groupby.filter(data[data['Education'] == 'Graduate'])
# Out:
# 0.5537459283387622

# %%
data[['Education', 'Loan_Status']]
# plot()
# Out:
#         Education Loan_Status
# 0        Graduate           Y
# 1        Graduate           N
# 2        Graduate           Y
# 3    Not Graduate           Y
# 4        Graduate           Y
# 5        Graduate           Y
# 6    Not Graduate           Y
# 7        Graduate           N
# 8        Graduate           Y
# 9        Graduate           N
# 10       Graduate           Y
# 11       Graduate           Y
# 12       Graduate           Y
# 13       Graduate           N
# 14       Graduate           Y
# 15       Graduate           Y
# 16   Not Graduate           Y
# 17       Graduate           N
# 18   Not Graduate           N
# 19       Graduate           Y
# 20   Not Graduate           N
# 21       Graduate           Y
# 22   Not Graduate           N
# 23   Not Graduate           N
# 24       Graduate           N
# 25       Graduate           Y
# 26       Graduate           Y
# 27   Not Graduate           Y
# 28   Not Graduate           N
# 29       Graduate           Y
# ...

# %%
data.groupby('Education').filter(lambda group: group==)
