# %%
import pandas as pd
import numpy as np
auto_mg_df = pd.DataFrame(pd.read_table("/Users/sam/All-Program/App-DataSet/IIT-Code/Data-Mining/datasets/auto-mpg.tab"))
auto_mg_df = auto_mg_df.ix[2:]
# print (auto_mg_df)
auto_mg_df.describe(include = 'all')
# Out:
#         mpg cylinders displacement horsepower weight acceleration model_year  \
# count   398       398          398        398    398          398        398
# unique  129         5           82         94    351           95         13
# top      13         4           97        150   1985         14.5         73
# freq     20       204           21         22      4           23         40
#
#        origin    car_name
# count     398         398
# unique      3         305
# top         1  ford pinto
# freq      249           6

# %%
# new_array_with_nan = np.array(auto_mg_df['horsepower'])
# indices = np.where(np.array(auto_mg_df['horsepower']) == "?")[0]
# new_array_with_nan[indices] = np.nan
# auto_mg_df['horsepower'] = new_array_with_nan
auto_mg_df_1 = auto_mg_df.replace('?',np.nan)
auto_mg_df.describe(include = 'all')
auto_mg_df
# Out:
#     mpg cylinders displacement horsepower weight acceleration model_year  \
# 2    18         8          307        130   3504           12         70
# 3    15         8          350        165   3693         11.5         70
# 4    18         8          318        150   3436           11         70
# 5    16         8          304        150   3433           12         70
# 6    17         8          302        140   3449         10.5         70
# 7    15         8          429        198   4341           10         70
# 8    14         8          454        220   4354            9         70
# 9    14         8          440        215   4312          8.5         70
# 10   14         8          455        225   4425           10         70
# 11   15         8          390        190   3850          8.5         70
# 12   15         8          383        170   3563           10         70
# 13   14         8          340        160   3609            8         70
# ...

# %%
mean_hpw = auto_mg_df_1['horsepower'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/sam/App-Setup/CondaENV/lib/python3.5/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#      99                 else:
# --> 100                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     101             except Exception:
#
# /Users/sam/App-Setup/CondaENV/lib/python3.5/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna)
#     292     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 293     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     294
#
# /Users/sam/App-Setup/CondaENV/lib/python3.5/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims)
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#
# ...
